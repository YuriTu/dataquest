# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering', 'Computer Science']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(9, 18))

for sp in range(0,17):
    pos = sp % 3
    if pos == 0:
        data = stem_cats
        index = int(sp / 3)
    elif pos == 1:
        data = lib_arts_cats
        index = int(sp / 3)
    else:
        data = other_cats
        index = int(sp / 3)
    if sp is 16:
        ax = fig.add_subplot(6,3,sp+2)
        data = other_cats
    else:
        ax = fig.add_subplot(6,3,sp+1)
    print(sp,pos,index)
    
    ax.plot(women_degrees['Year'], women_degrees[data[index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[data[index]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(data[index])
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 15:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()
# Out:
# 0 0 0
# 1 1 0
# 2 2 0
# 3 0 1
# 4 1 1
# 5 2 1
# 6 0 2
# 7 1 2
# 8 2 2
# 9 0 3
# 10 1 3
# 11 2 3
# 12 0 4
# 13 1 4
# 14 2 4
# 15 0 5
# 16 1 5

# %%
fig = plt.figure(figsize=(9, 18))
for sp in range(0,17):
    pos = sp % 3
    if pos == 0:
        data = stem_cats
        index = int(sp / 3)
    elif pos == 1:
        data = lib_arts_cats
        index = int(sp / 3)
    else:
        data = other_cats
        index = int(sp / 3)
    if sp is 16:
        ax = fig.add_subplot(6,3,sp+2)
        data = other_cats
    else:
        ax = fig.add_subplot(6,3,sp+1)
    print(sp,pos,index)
    
    ax.plot(women_degrees['Year'], women_degrees[data[index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[data[index]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(data[index])
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom = "off")
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 15:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = "on")
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom = "on")
        
    if sp == 13:
        ax.tick_params(labelbottom = "on")
plt.show()
# Out:
# 0 0 0
# 1 1 0
# 2 2 0
# 3 0 1
# 4 1 1
# 5 2 1
# 6 0 2
# 7 1 2
# 8 2 2
# 9 0 3
# 10 1 3
# 11 2 3
# 12 0 4
# 13 1 4
# 14 2 4
# 15 0 5
# 16 1 5

# %%
fig = plt.figure(figsize=(9, 18))
for sp in range(0,17):
    pos = sp % 3
    if pos == 0:
        data = stem_cats
        index = int(sp / 3)
    elif pos == 1:
        data = lib_arts_cats
        index = int(sp / 3)
    else:
        data = other_cats
        index = int(sp / 3)
    if sp is 16:
        ax = fig.add_subplot(6,3,sp+2)
        data = other_cats
    else:
        ax = fig.add_subplot(6,3,sp+1)
    print(sp,pos,index)
    
    ax.plot(women_degrees['Year'], women_degrees[data[index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[data[index]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(data[index])
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom = "off")
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 15:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = "on")
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom = "on")
        
    if sp == 13:
        ax.tick_params(labelbottom = "on")
plt.show()
# Out:
# 0 0 0
# 1 1 0
# 2 2 0
# 3 0 1
# 4 1 1
# 5 2 1
# 6 0 2
# 7 1 2
# 8 2 2
# 9 0 3
# 10 1 3
# 11 2 3
# 12 0 4
# 13 1 4
# 14 2 4
# 15 0 5
# 16 1 5

# %%
fig = plt.figure(figsize=(9, 18))
for sp in range(0,17):
    pos = sp % 3
    if pos == 0:
        data = stem_cats
        index = int(sp / 3)
    elif pos == 1:
        data = lib_arts_cats
        index = int(sp / 3)
    else:
        data = other_cats
        index = int(sp / 3)
    if sp is 16:
        ax = fig.add_subplot(6,3,sp+2)
        data = other_cats
    else:
        ax = fig.add_subplot(6,3,sp+1)
    print(sp,pos,index)
    
    ax.plot(women_degrees['Year'], women_degrees[data[index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[data[index]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(data[index])
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom = "off")
    ax.axhline(50,c = (171/255,171/255,171/255),alpha=0.3)
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 15:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = "on")
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom = "on")
        
    if sp == 13:
        ax.tick_params(labelbottom = "on")
plt.show()
# Out:
# 0 0 0
# 1 1 0
# 2 2 0
# 3 0 1
# 4 1 1
# 5 2 1
# 6 0 2
# 7 1 2
# 8 2 2
# 9 0 3
# 10 1 3
# 11 2 3
# 12 0 4
# 13 1 4
# 14 2 4
# 15 0 5
# 16 1 5
